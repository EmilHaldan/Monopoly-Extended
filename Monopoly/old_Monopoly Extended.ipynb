# %% [markdown]
# ## Monopoly Extended !
# This version of monopoly has been added to give some spice to the good old game that we all love. The changes in this version promise for a more diverse gameplay with unique chance cards, unique features, and other unlucky and lucky additions.

# %% [markdown]
# ### Monopoly Extended Rules !

# %%
### Global Variables 

players = {}
playersorder = []
yes_list = ['yes', 'yea', 'yup', 'y']

pass_go_cash = 200
start_money = 2000

invest_std = 0.15
invest_mean = 1.1


Brown_1 = {"name": "Old Kent Road" , "price": 60 , "rent":0, "level" : 1 , "owner": None, "side": "South"} 
Brown_2 = {"name": "Whitechapel Road" , "price": 60 , "rent":0, "level" : 1 , "owner": None, "side": "South"} 
Grey_1 = {"name": "The Angel Islington", "price": 100 , "rent":0, "level" : 1 , "owner": None, "side": "South"}
Grey_2 = {"name": "Euston Road", "price": 100 , "rent":0, "level" : 1 , "owner": None, "side": "South"}
Grey_3 = {"name": "Pentonville Road", "price": 120 , "rent":0, "level" : 1 , "owner": None, "side": "South"}
Pink_1 = {"name": "Pall Mall", "price": 140 , "rent":0, "level" : 1 , "owner": None, "side": "West"}
Pink_2 = {"name": "Whitehall", "price": 140 , "rent":0, "level" : 1 , "owner": None, "side": "West"}
Pink_3 = {"name": "Northumberland Avenue", "price": 160 , "rent":0, "level" : 1 , "owner": None, "side": "West"}
Orange_1 = {"name": "Bow Street", "price": 180 , "rent":0, "level" : 1 , "owner": None, "side": "West"}
Orange_2 = {"name": "Marlborough Street" , "price": 180 , "rent":0, "level" : 1 , "owner": None, "side": "West"}
Orange_3 = {"name": "Vine Street", "price": 200 , "rent":0, "level" : 1 , "owner": None, "side": "West"}
Red_1 = {"name": "Strand", "price": 220 , "rent":0, "level" : 1 , "owner": None, "side": "North"}
Red_2 = {"name": "Fleet Street", "price": 220 , "rent":0, "level" : 1 , "owner": None, "side":"North"}
Red_3 = {"name": "Trafalgar Square", "price": 240 , "rent":0, "level" : 1 , "owner": None, "side":"North"}
Yellow_1 = {"name": "Leicester Square", "price": 260 , "rent":0, "level" : 1 , "owner": None, "side":"North"}
Yellow_2 = {"name": "Coventry Street", "price": 260 , "rent":0, "level" : 1 , "owner": None, "side":"North"}
Yellow_3 = {"name": "Piccadilly", "price": 280 , "rent":0, "level" : 1 , "owner": None, "side":"North"}
Green_1 = {"name": "Regent Street", "price": 300 , "rent":0, "level" : 1 , "owner": None, "side":"East"}
Green_2 = {"name": "Oxford Street", "price": 300 , "rent":0, "level" : 1 , "owner": None, "side":"East"}
Green_3 = {"name": "Bond Street", "price": 320 , "rent":0, "level" : 1 , "owner": None, "side":"East"}
Blue_1  = {"name": "Park Lane", "price": 350 , "rent":0, "level" : 1 , "owner": None, "side":"East"}
Blue_2  = {"name": "Mayfair", "price": 400 , "rent":0, "level" : 1 , "owner": None, "side":"East"}


All_property_list = [Brown_1,Brown_2,Grey_1,Grey_2,Grey_3,Pink_1,Pink_2,Pink_3,Orange_1,Orange_2,Orange_3,Red_1,Red_2,Red_3,
               Yellow_1,Yellow_2,Yellow_3,Green_1,Green_2,Green_3,Blue_1,Blue_2]

# %%
# Imports 
import numpy as np
import time
import random as rn

# %%
def clearscreen():
    for _ in range(20):
        print("")

# %%
def start_the_game():
    #clearscreen()
    print("")
    print("")
    print("")
    print("                                $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$    ")
    print("                                $$                             $$    ")
    print("                                $$       MONOPOLY REMADE       $$    ")
    print("                                $$                             $$    ")
    print("                                $$        First Edition        $$    ")
    print("                                $$                             $$    ")
    print("                                $$                             $$    ")
    print("                                $$       by Emil Haldan        $$    ")
    print("                                $$                             $$    ")
    print("                                $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$    ")
    print("")
    print("")
    print("")
    print("")
    print("")
    print("              ##################################################################")
    print("")
    print("                                  How many players are you ?:  ")
    print("")
    print("                                  Type an integer, such as 2,3 or 4! ")
    print("")
    print("")
    print("")
    print("")
    print("")
    print("")
    print("")
    print("")
    time.sleep(1)
    player_amount = input()
    int(player_amount)      
    print("")    
    print("")
    print("                              ##############################")
    print("")
    print("                                  Type in your names:")
    print("")
    for i in range(0, int(player_amount)):
        x = input()
        players[x] = {"Wallet": start_money, "Property": [], "Investment": 0 , "Luck": 0.5, "Placement": 0}
        playersorder.append(x)
    
    roundcount = 0
    while roundcount < 3:
        roundcount += 1
        one_round(roundcount)

# %%
# Creating the Game board 

Start = 0
Event = 0
Location_icon = 0 
Visit_jail = 0
Go_to_jail = 0
Free_park = 0

board_placement = {0: "Start" , 1: Brown_1, 2:"Event" , 3: Brown_2, 4: "Event", 5: Grey_1, 6: Grey_2, 7: "Location_icon", 
                   8: Grey_3, 9:"Visit_jail", 10: Pink_1 , 11: "Event", 12: Pink_2, 13: Pink_3, 14: Orange_1 ,
                   15: Orange_2, 16: "Location_icon", 17: Orange_3 , 18: "Free_park" , 19: Red_1, 20: "Event",
                   21: Red_2, 22: Red_3, 23:Yellow_1 , 24:Yellow_2 , 25: "Location_icon" , 26: Yellow_3 ,
                   27: "Go_to_jail", 28: Green_1, 29: "Event", 30: Green_2, 31: Green_3, 32: "Event" , 33: Blue_1
                   , 34: "Location_icon", 35:Blue_2 , "jail": "Jail"}

# %%
def player_info(player):
    print(" #----------------------------------------------------------------------# ")
    print(" {}'s Wallet      : ".format(player), players[player]['Wallet'])
    print(" {}'s Investments : ".format(player), players[player]['Investment'])
    print(" {}'s Property    : ".format(player))
    players[player]['Property'].sort()
    for prop in players[player]['Property']:
        print(prop['name'])
    print(" #----------------------------------------------------------------------# ")
    
    
Blue_2  = {"name": "Mayfair", "price": 400 , "rent":0, "level" : 1 , "owner": None, "side":"East"}

def landed_on(player):
    cur_placement = board_placement[players[player]['Placement']]
    if type(cur_placement) != str:  # Only properties have values in board_placement dict which are NOT strings.
        if cur_placement["owner"] == None:
            print("Do you wish to purchse", cur_placement['name'], "for ", cur_placement['price'], " ?")
            buy = input()
            if buy in yes_list:
                cur_placement['owner'] = player                      # changing owner
                players[player]['Property'].append(cur_placement)    # Adding property to owners list
                players[player]['Wallet'] -= cur_placement['price']          
                # BUY
            else:
                pass
                start_auction(player, prop)
                # AUCTION
            
        elif cur_placement["owner"] == player:
            cur_placement['level'] += 1
            # Upgade house by 1 level for free
        else:
            #Pay rent from player to owner
            pass
        
        
        # THE PERSON LANDED ON A PROPERTY, they can either Buy it, pay rent, or stay for free if they own it. 
        pass
    else: 
        if cur_placement == "Jail":
            #Pay or Roll
            pass
            
        elif cur_placement == "Free_park":
            #Lottery
            pass
            
        elif cur_placement == "Location_icon":
            #Options to do shit for 100$ or/and trade or stuff idk? 
            pass
            
        elif cur_placement == "Event":
            # Take a choice of Event cards, Chance, Extreme Chance, etc. 
            pass
            
        elif cur_placement == "Go_to_jail":
            # Set placement of that person to jail.
            pass
            
        else: 
            pass
            
            
        
def dice_roll(player):
    extraturn = False
    print("")
    print(" Rolling dice!!! ")
    print("")
    time.sleep(1)
    print(" The dice are loose! ")
    print("")
    time.sleep(1)
    print("")
    roll_1 = rn.randint(1, 6)
    roll_2 = rn.randint(1, 6)
    
    if roll_1 == roll_2:
        extraturn=True
        
    roll = roll_1 + roll_2
    print(" You rolled : " , roll_1 , "and" , roll_2 )
    print(" Move your brick {} steps".format(roll))
    print("")
    print("")
    print(" Continue when you have moved your brick. ")
    print("")
    input(" Press Enter to continue...")
    
    players[player]['Placement'] += int(roll)
    if players[player]['Placement'] >= 36:
        players[player]['Placement'] = players[player]['Placement'] % 36
        players[player]['Wallet'] += pass_go_cash
    
    landed_on(player)
    
    if extraturn == True:
        dice_roll(player)
        
    
    
def turn_menu(player):
    print("___________________________________________________________________")
    print("")
    print("  1. Buy/Upgrade Property")
    print("  2. Trade ")
    print("  3. Arrange an Auction")
    print("")
    print("___________________________________________________________________")


def one_turn(player):
    print("")
    print("  #################################   ")
    print("  ###                           ###  ")
    print("  ###     {:<17}     ### ".format(player+"'s Turn!"))
    print("  ###                           ###  ")
    print("  #################################   ")
    print("")
    player_info(player)
    print("")
    dice_roll(player)
    print("")
    print("")


def one_round(roundcount):
    print("")
    print("  $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ ")
    print(" $                               $")
    print(" $      START OF NEW ROUND       $")
    print(" $                               $")
    print("  $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ ")
    print("")
    print("   It is round # ", roundcount)
    print("")
    print("")
    for player in playersorder:
        one_turn(player)
        
        
def start_auction(player, prop):
    pass


def rent(): 
    pass

# %%
players = {}
playersorder = []

start_the_game()
# Out:
#                                 $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#                                 $$                             $$
#                                 $$       MONOPOLY REMADE       $$
#                                 $$                             $$
#                                 $$        First Edition        $$
#                                 $$                             $$
#                                 $$                             $$
#                                 $$       by Emil Haldan        $$
#                                 $$                             $$
#                                 $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#
#
#
#
#
#               ##################################################################
#
#                                   How many players are you ?:
#
#                                   Type an integer, such as 2,3 or 4!
#
#
#
#
#
#
#
#
# 2
#
#
#                               ##############################
# ...
